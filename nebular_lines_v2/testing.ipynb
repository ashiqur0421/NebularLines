# %%
import os
import sys
import copy

import numpy as np
import yt
from yt.frontends.ramses.field_handlers import RTFieldFileHandler

from emission import EmissionLineInterpolator
import galaxy_visualization

# %%
# filename = "/Users/bnowicki/Documents/Research/Ricotti/output_00273/info_00273.txt"
filename = "C:/Users/ashiq/OneDrive/Desktop/GEMSTONE/yt_Aether/Braden/output_00273/output_00273/info_00273.txt"

lines=["H1_6562.80A","O1_1304.86A","O1_6300.30A","O2_3728.80A","O2_3726.10A",
       "O3_1660.81A","O3_1666.15A","O3_4363.21A","O3_4958.91A","O3_5006.84A", 
       "He2_1640.41A","C2_1335.66A","C3_1906.68A","C3_1908.73A","C4_1549.00A",
       "Mg2_2795.53A","Mg2_2802.71A","Ne3_3868.76A","Ne3_3967.47A",
       "N5_1238.82A",
       "N5_1242.80A","N4_1486.50A","N3_1749.67A","S2_6716.44A","S2_6730.82A"]

wavelengths=[6562.80, 1304.86, 6300.30, 3728.80, 3726.10, 1660.81, 1666.15,
             4363.21, 4958.91, 5006.84, 1640.41, 1335.66,
             1906.68, 1908.73, 1549.00, 2795.53, 2802.71, 3868.76,
             3967.47, 1238.82, 1242.80, 1486.50, 1749.67, 6716.44, 6730.82]

cell_fields = [
    "Density",
    "x-velocity",
    "y-velocity",
    "z-velocity",
    "Pressure",
    "Metallicity",
    "xHI",
    "xHII",
    "xHeII",
    "xHeIII",
]

epf = [
    ("particle_family", "b"),
    ("particle_tag", "b"),
    ("particle_birth_epoch", "d"),
    ("particle_metallicity", "d"),
]

# Ionization Parameter Field
# Based on photon densities in bins 2-4
# Don't include bin 1 -> Lyman Werner non-ionizing
def _ion_param(field, data):
    p = RTFieldFileHandler.get_rt_parameters(ds).copy()
    p.update(ds.parameters)

    cgs_c = 2.99792458e10     #light velocity

    # Convert to physical photon number density in cm^-3
    pd_2 = data['ramses-rt','Photon_density_2']*p["unit_pf"]/cgs_c
    pd_3 = data['ramses-rt','Photon_density_3']*p["unit_pf"]/cgs_c
    pd_4 = data['ramses-rt','Photon_density_4']*p["unit_pf"]/cgs_c

    photon = pd_2 + pd_3 + pd_4

    return photon/data['gas', 'number_density']


def _my_temperature(field, data):
    #y(i): abundance per hydrogen atom
    XH_RAMSES=0.76 #defined by RAMSES in cooling_module.f90
    YHE_RAMSES=0.24 #defined by RAMSES in cooling_module.f90
    mH_RAMSES=yt.YTArray(1.6600000e-24,"g") #defined by RAMSES in cooling_module.f90
    kB_RAMSES=yt.YTArray(1.3806200e-16,"erg/K") #defined by RAMSES in cooling_module.f90

    dn=data["ramses","Density"].in_cgs()
    pr=data["ramses","Pressure"].in_cgs()
    yHI=data["ramses","xHI"]
    yHII=data["ramses","xHII"]
    yHe = YHE_RAMSES*0.25/XH_RAMSES
    yHeII=data["ramses","xHeII"]*yHe
    yHeIII=data["ramses","xHeIII"]*yHe
    yH2=1.-yHI-yHII
    yel=yHII+yHeII+2*yHeIII
    mu=(yHI+yHII+2.*yH2 + 4.*yHe) / (yHI+yHII+yH2 + yHe + yel)
    return pr/dn * mu * mH_RAMSES / kB_RAMSES


# TODO see if it works in emission.py
# Luminosity field
# Cloudy Intensity obtained assuming height = 1cm
# Return intensity values erg/s/cm**2
# Multiply intensity at each pixel by volume of pixel -> luminosity
def get_luminosity(line):
   def _luminosity(field, data):
      return data['gas', 'flux_' + line]*data['gas', 'volume']
   return copy.deepcopy(_luminosity)


#number density of hydrogen atoms
def _my_H_nuclei_density(field, data):
    dn=data["ramses","Density"].in_cgs()
    XH_RAMSES=0.76 #defined by RAMSES in cooling_module.f90
    YHE_RAMSES=0.24 #defined by RAMSES in cooling_module.f90
    mH_RAMSES=yt.YTArray(1.6600000e-24,"g") #defined by RAMSES in cooling_module.f90

    return dn*XH_RAMSES/mH_RAMSES


def _pressure(field, data):
    if 'hydro_thermal_pressure' in dir(ds.fields.ramses): # and 
        #'Pressure' not in dir(ds.fields.ramses):
        return data['ramses', 'hydro_thermal_pressure']


def _xHI(field, data):
    if 'hydro_xHI' in dir(ds.fields.ramses): # and \
        #'xHI' not in dir(ds.fields.ramses):
        return data['ramses', 'hydro_xHI']


def _xHII(field, data):
    if 'hydro_xHII' in dir(ds.fields.ramses): # and \
        #'xHII' not in dir(ds.fields.ramses):
        return data['ramses', 'hydro_xHII']


def _xHeII(field, data):
    if 'hydro_xHeII' in dir(ds.fields.ramses): # and \
        #'xHeII' not in dir(ds.fields.ramses):
        return data['ramses', 'hydro_xHeII']


def _xHeIII(field, data):
    if 'hydro_xHeIII' in dir(ds.fields.ramses): # and \
        #'xHeIII' not in dir(ds.fields.ramses):
        return data['ramses', 'hydro_xHeIII']

# %%
'''
-------------------------------------------------------------------------------
Load Simulation Data
Add Derived Fields
-------------------------------------------------------------------------------
'''

ds = yt.load(filename, extra_particle_fields=epf)

ds.add_field(
    ("gas","number_density"),
    function=_my_H_nuclei_density,
    sampling_type="cell",
    units="1/cm**3",
    force_override=True
)


ds.add_field(
    ("ramses","Pressure"),
    function=_pressure,
    sampling_type="cell",
    units="1",
    #force_override=True
)

ds.add_field(
    ("ramses","xHI"),
    function=_xHI,
    sampling_type="cell",
    units="1",
    #force_override=True
)

ds.add_field(
    ("ramses","xHII"),
    function=_xHII,
    sampling_type="cell",
    units="1",
    #force_override=True
)

ds.add_field(
    ("ramses","xHeII"),
    function=_xHeII,
    sampling_type="cell",
    units="1",
    #force_override=True
)

ds.add_field(
    ("ramses","xHeIII"),
    function=_xHeIII,
    sampling_type="cell",
    units="1",
    #force_override=True
)

ds.add_field(
    ("gas","my_temperature"),
    function=_my_temperature,
    sampling_type="cell",
    # TODO units
    #units="K",
    #units="K*cm**3/erg",
    units='K*cm*dyn/erg',
    force_override=True
)

# Ionization parameter
ds.add_field(
    ('gas', 'ion_param'),
    function=_ion_param,
    sampling_type="cell",
    units="cm**3",
    force_override=True
)

ds.add_field(
    ("gas","my_H_nuclei_density"),
    function=_my_H_nuclei_density,
    sampling_type="cell",
    units="1/cm**3",
    force_override=True
)

# Normalize by Density Squared Flag
dens_normalized = True
if dens_normalized: 
    units = '1/cm**6'
else:
    units = '1'

# Instance of EmissionLineInterpolator for line list at filename
line_list = os.path.join(os.getcwd(), 'linelist.dat')
emission_interpolator = EmissionLineInterpolator(line_list, lines)

# Add flux and luminosity fields for all lines in the list
for i, line in enumerate(lines):
    ds.add_field(
        ('gas', 'flux_' + line),
        function=emission_interpolator.get_line_emission(
            i, dens_normalized=dens_normalized
        ),
        sampling_type='cell',
        units=units,
        force_override=True
    )
    # TODO change get_line_emission to accept line not idx

    ds.add_field(
        ('gas', 'luminosity_' + line),
        function=emission_interpolator.get_luminosity(lines[i]),
        #function=get_luminosity(lines[i]),
        sampling_type='cell',
        units='1/cm**3',
        force_override=True
    )

ad = ds.all_data()
print(ds.field_list)
# Out:
# yt : [INFO     ] 2025-04-24 08:52:17,239 Parameters: current_time              = 4.311420483661945
# yt : [INFO     ] 2025-04-24 08:52:17,242 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2025-04-24 08:52:17,244 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-04-24 08:52:17,246 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-04-24 08:52:17,248 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-04-24 08:52:17,248 Parameters: current_redshift          = 12.171087046255657
# yt : [INFO     ] 2025-04-24 08:52:17,249 Parameters: omega_lambda              = 0.685000002384186
# yt : [INFO     ] 2025-04-24 08:52:17,250 Parameters: omega_matter              = 0.314999997615814
# yt : [INFO     ] 2025-04-24 08:52:17,250 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-04-24 08:52:17,250 Parameters: hubble_constant           = 0.674000015258789
# yt : [WARNING  ] 2025-04-24 08:52:34,663 This output has no cooling fields
# yt : [WARNING  ] 2025-04-24 08:52:36,568 The DM particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,573 The star particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,576 The cloud particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,580 The dust particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,582 The star_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,583 The cloud_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,584 The dust_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2025-04-24 08:52:36,586 The gas_tracer particle filter already exists. Overriding.
# yt : [INFO     ] 2025-04-24 08:52:36,588 Adding particle_type: DM
# yt : [INFO     ] 2025-04-24 08:52:36,634 Adding particle_type: star
# yt : [INFO     ] 2025-04-24 08:52:36,674 Adding particle_type: cloud
# yt : [INFO     ] 2025-04-24 08:52:36,704 Adding particle_type: dust
# yt : [INFO     ] 2025-04-24 08:52:36,736 Adding particle_type: star_tracer
# yt : [INFO     ] 2025-04-24 08:52:36,777 Adding particle_type: cloud_tracer
# yt : [INFO     ] 2025-04-24 08:52:41,242 Adding particle_type: dust_tracer
# yt : [INFO     ] 2025-04-24 08:52:41,275 Adding particle_type: gas_tracer
# yt : [WARNING  ] 2025-04-24 08:52:41,306 Field ('ramses', 'Pressure') already exists. To override use `force_override=True`.
# minU=-6.0, maxU=1.0, stepU=0.5, minN=-1.0, maxN=6.0, stepN=0.5, minT=3.0, maxT=6.0, stepT=0.1
# Line List Shape = (25, 6975)
# 15 15 31
# [('gravity', 'Potential'), ('gravity', 'x-acceleration'), ('gravity', 'y-acceleration'), ('gravity', 'z-acceleration'), ('io', 'particle_birth_epoch'), ('io', 'particle_family'), ('io', 'particle_identity'), ('io', 'particle_mass'), ('io', 'particle_metallicity'), ('io', 'particle_position_x'), ('io', 'particle_position_y'), ('io', 'particle_position_z'), ('io', 'particle_refinement_level'), ('io', 'particle_tag'), ('io', 'particle_velocity_x'), ('io', 'particle_velocity_y'), ('io', 'particle_velocity_z'), ('nbody', 'particle_mass'), ('nbody', 'particle_position_x'), ('nbody', 'particle_position_y'), ('nbody', 'particle_position_z'), ('nbody', 'particle_velocity_x'), ('nbody', 'particle_velocity_y'), ('nbody', 'particle_velocity_z'), ('ramses', 'Density'), ('ramses', 'Metallicity'), ('ramses', 'Pressure'), ('ramses', 'hydro_i_level'), ('ramses', 'hydro_xHI'), ('ramses', 'hydro_xHII'), ('ramses', 'hydro_xHeII'), ('ramses', 'hydro_xHeIII'), ('ramses', 'x-velocity'), ('ramses', 'y-velocity'), ('ramses', 'z-velocity'), ('ramses-rt', 'Photon_density_1'), ('ramses-rt', 'Photon_density_2'), ('ramses-rt', 'Photon_density_3'), ('ramses-rt', 'Photon_density_4'), ('ramses-rt', 'Photon_flux_x_1'), ('ramses-rt', 'Photon_flux_x_2'), ('ramses-rt', 'Photon_flux_x_3'), ('ramses-rt', 'Photon_flux_x_4'), ('ramses-rt', 'Photon_flux_y_1'), ('ramses-rt', 'Photon_flux_y_2'), ('ramses-rt', 'Photon_flux_y_3'), ('ramses-rt', 'Photon_flux_y_4'), ('ramses-rt', 'Photon_flux_z_1'), ('ramses-rt', 'Photon_flux_z_2'), ('ramses-rt', 'Photon_flux_z_3'), ('ramses-rt', 'Photon_flux_z_4'), ('sink', 'particle_BH_spin_x'), ('sink', 'particle_BH_spin_y'), ('sink', 'particle_BH_spin_z'), ('sink', 'particle_delta_mass'), ('sink', 'particle_identifier'), ('sink', 'particle_mass'), ('sink', 'particle_position_x'), ('sink', 'particle_position_y'), ('sink', 'particle_position_z'), ('sink', 'particle_prop_0_0'), ('sink', 'particle_prop_1_0'), ('sink', 'particle_real_accretion'), ('sink', 'particle_tsink'), ('sink', 'particle_velocity_x'), ('sink', 'particle_velocity_y'), ('sink', 'particle_velocity_z'), ('sink_csv', 'particle_         1'), ('sink_csv', 'particle_    1.0896337441E-18'), ('sink_csv', 'particle_    1.2864646199E-04'), ('sink_csv', 'particle_    1.8873961292E-14'), ('sink_csv', 'particle_    4.9117193911E-01'), ('sink_csv', 'particle_    4.9278276910E-01'), ('sink_csv', 'particle_    4.9474984927E-01'), ('sink_csv', 'particle_    8.8610840417E-30'), ('sink_csv', 'particle_   -1.2891207684E-04'), ('sink_csv', 'particle_   -2.8898711554E-30'), ('sink_csv', 'particle_   -4.2731908022E-30'), ('sink_csv', 'particle_   -7.0614810844E-04'), ('sink_csv', 'particle_   -7.9354670769E+00')]

# %%
'''
-------------------------------------------------------------------------------
Run routines on data
-------------------------------------------------------------------------------
'''

viz = galaxy_visualization.VisualizationManager(filename, lines, wavelengths)
star_ctr = viz.star_center(ad)
sp = ds.sphere(star_ctr, (3000, "pc"))
sp_lum = ds.sphere(star_ctr, (10, 'kpc'))
width = (1500, 'pc')

sim_run = filename.split('/')[-1]

field_list = [
    #('gas', 'temperature'),
    ('gas', 'density'),
    ('gas', 'my_H_nuclei_density'),
    ('gas', 'my_temperature'),
    ('gas', 'ion_param'),
    ('gas', 'metallicity'),
]

weight_field_list = [
    #('gas', 'my_H_nuclei_density'),
    ('gas', 'my_H_nuclei_density'),
    ('gas', 'my_H_nuclei_density'),
    ('gas', 'my_H_nuclei_density'),
    ('gas', 'my_H_nuclei_density'),
    ('gas', 'my_H_nuclei_density')
]

title_list = [
    #'Temperature [K]',
    r'Density [g cm$^{-3}$]',
    r'H Nuclei Number Density [cm$^{-3}$]',
    'My Temperature [K]',
    'Ionization Parameter',
    'Metallicity'
]


for line in lines:
    if line == 'H1_6562.80A':
        line_title = r'H$\alpha$_6562.80A'
    else:
        line_title = line

    field_list.append(('gas', 'flux_'  + line))
    title_list.append(line_title.replace('_', ' ') + 
                      r' Flux [$erg\: s^{-1}\: cm^{-2}$]')
    weight_field_list.append(None)

    field_list.append(('gas', 'luminosity_'  + line))
    title_list.append(line_title.replace('_', ' ') + 
                      r' Luminosity [$erg\: s^{-1}$]')
    weight_field_list.append(None)


viz.save_sim_info(ds)
viz.plot_wrapper(ds, sp, width, star_ctr, field_list,
                     weight_field_list, title_list, proj=True, slc=False)

# %%
viz.plot_wrapper(ds, sp, width, star_ctr, [('gas', 'my_temperature')],
                     [('gas', 'my_H_nuclei_density')], ['my temperature'], proj=True, slc=False)

#viz.plot_wrapper(ds, sp, width, star_ctr, [('ramses', 'xHII'), ('ramses', 'xHeII'), ('ramses', 'xHeIII')],
#                     [('gas', 'my_H_nuclei_density'), ('gas', 'my_H_nuclei_density'), ('gas', 'my_H_nuclei_density')], ['xHII', 'xHeII', 'xHeIII'], proj=True, slc=False)
# Out:
# yt : [INFO     ] 2025-03-27 16:13:05,739 Identified   375/  384 intersecting domains (  375 through hilbert key indexing)
# yt : [INFO     ] 2025-03-27 16:13:09,094 Projection completed
# yt : [INFO     ] 2025-03-27 16:13:09,095 xlim = 0.490978 0.491364
# yt : [INFO     ] 2025-03-27 16:13:09,095 ylim = 0.492583 0.492970
# yt : [INFO     ] 2025-03-27 16:13:09,096 xlim = 0.490978 0.491364
# yt : [INFO     ] 2025-03-27 16:13:09,097 ylim = 0.492583 0.492970
# yt : [INFO     ] 2025-03-27 16:13:09,098 Making a fixed resolution buffer of (('gas', 'my_temperature')) 1000 by 1000

# %%
print(ad['ramses', 'Pressure'].units)
# Out:
# code_pressure

# %%
extrema = {('gas', 'my_temperature'): (1e3, 1e8),
           ('gas', 'my_H_nuclei_density'): (1e-4, 1e4)}

line_title = r'H$\alpha$_6562.80A'

viz.phase_plot(ds, sp, x_field=('gas', 'my_temperature'),
               y_field=('gas', 'my_H_nuclei_density'), z_field=('gas', 'flux_H1_6562.80A'),
               extrema=extrema, x_label='Temperature [K]', 
               y_label=r'H Nuclei Number Density [cm$^{-3}$]', 
               z_label=line_title.replace('_', ' ') + 
                      r' Flux [erg s$^{-1}$ cm$^{-2}$]')
# Out:
# yt : [INFO     ] 2025-04-03 15:28:37,814 Saving plot analysis/output_00273_analysis/output_00273_my_temperature_my_H_nuclei_density_flux_H1_6562.80A_phase.png

# %%
viz.calc_luminosities(sp)
# Out:
# H1_6562.80A Luminosity = 8.834081984412808e+41 cm**(-3) erg/s
# O1_1304.86A Luminosity = 5.130504462828963e+34 cm**(-3) erg/s
# O1_6300.30A Luminosity = 8.398072130951248e+36 cm**(-3) erg/s
# O2_3728.80A Luminosity = 1.4453069758064272e+37 cm**(-3) erg/s
# O2_3726.10A Luminosity = 2.6456051389974314e+37 cm**(-3) erg/s
# O3_1660.81A Luminosity = 7.609348442388433e+35 cm**(-3) erg/s
# O3_1666.15A Luminosity = 2.2284170286228816e+36 cm**(-3) erg/s
# O3_4363.21A Luminosity = 8.756333174869612e+35 cm**(-3) erg/s
# O3_4958.91A Luminosity = 8.348039861471982e+36 cm**(-3) erg/s
# O3_5006.84A Luminosity = 2.4907174062091733e+37 cm**(-3) erg/s
# He2_1640.41A Luminosity = 1.4251693123545895e+38 cm**(-3) erg/s
# C2_1335.66A Luminosity = 4.187353508012613e+35 cm**(-3) erg/s
# C3_1906.68A Luminosity = 1.3738911794389046e+37 cm**(-3) erg/s
# C3_1908.73A Luminosity = 1.1674005577107624e+37 cm**(-3) erg/s
# C4_1549.00A Luminosity = 3.985881378576702e+29 cm**(-3) erg/s
# Mg2_2795.53A Luminosity = 3.5391771044188585e+37 cm**(-3) erg/s
# Mg2_2802.71A Luminosity = 1.7879308190464272e+37 cm**(-3) erg/s
# Ne3_3868.76A Luminosity = 5.25355092292995e+35 cm**(-3) erg/s
# Ne3_3967.47A Luminosity = 1.594532437583773e+35 cm**(-3) erg/s
# N5_1238.82A Luminosity = 9.192835419192301e+32 cm**(-3) erg/s
# N5_1242.80A Luminosity = 4.5861015696870936e+32 cm**(-3) erg/s
# N4_1486.50A Luminosity = 9.815149740533653e+32 cm**(-3) erg/s
# N3_1749.67A Luminosity = 1.1849629873646143e+36 cm**(-3) erg/s
# S2_6716.44A Luminosity = 8.419416972334938e+36 cm**(-3) erg/s
# S2_6730.82A Luminosity = 1.280719205619181e+37 cm**(-3) erg/s
# [array(8.83408198e+41),
#  array(5.13050446e+34),
#  array(8.39807213e+36),
#  array(1.44530698e+37),
#  array(2.64560514e+37),
#  array(7.60934844e+35),
#  array(2.22841703e+36),
#  array(8.75633317e+35),
#  array(8.34803986e+36),
#  array(2.49071741e+37),
#  array(1.42516931e+38),
#  array(4.18735351e+35),
#  array(1.37389118e+37),
#  array(1.16740056e+37),
#  array(3.98588138e+29),
#  array(3.5391771e+37),
#  array(1.78793082e+37),
#  array(5.25355092e+35),
#  array(1.59453244e+35),
#  array(9.19283542e+32),
#  array(4.58610157e+32),
#  array(9.81514974e+32),
#  array(1.18496299e+36),
#  array(8.41941697e+36),
#  array(1.28071921e+37)]

# %%
viz.save_sim_field_info(ds, sp)
# Out:
# yt : [INFO     ] 2025-03-26 17:06:03,789 Identified   375/  384 intersecting domains (  375 through hilbert key indexing)
# /Users/bnowicki/miniforge3/lib/python3.10/site-packages/yt/frontends/ramses/fields.py:241: RuntimeWarning: Trying to calculate temperature but the cooling tables couldn't be found or read. yt will return T/µ instead of T — this is equivalent to assuming µ=1.0. To suppress this, derive the temperature from temperature_over_mu with some values for mu.
#   warnings.warn(
# ('gas', 'temperature')_min: 107.84208924098935 K
# ('gas', 'temperature')_min: 7698681.45311589 K
# ('gas', 'temperature')_min: 11066.681760870284 K
# ('gas', 'temperature')_min: 19014518067.84682 K
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K'))]
# ('gas', 'density')_min: 4.606967828146415e-28 g/cm**3
# ('gas', 'density')_min: 2.7571580882186567e-19 g/cm**3
# ('gas', 'density')_min: 1.7727794350437144e-21 g/cm**3
# ('gas', 'density')_min: 3.0459488513651044e-15 g/cm**3
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3'))]
# ('gas', 'my_H_nuclei_density')_min: 0.00021092141863802863 cm**(-3)
# ('gas', 'my_H_nuclei_density')_min: 126231.33415940838 cm**(-3)
# ('gas', 'my_H_nuclei_density')_min: 811.6339582127848 cm**(-3)
# ('gas', 'my_H_nuclei_density')_min: 1394530799.420168 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)'))]
# ('gas', 'my_temperature')_min: 130.40954755321593 K*cm*dyn/erg
# ('gas', 'my_temperature')_min: 4491566.845997048 K*cm*dyn/erg
# ('gas', 'my_temperature')_min: 9055.695437262044 K*cm*dyn/erg
# ('gas', 'my_temperature')_min: 15559287619.308586 K*cm*dyn/erg
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg'))]
# ('gas', 'ion_param')_min: 1.7965416637872678e-51 cm**3
# ('gas', 'ion_param')_min: 10.020006799898477 cm**3
# ('gas', 'ion_param')_min: 0.002309571556852271 cm**3
# ('gas', 'ion_param')_min: 3968.252728837765 cm**3
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3'))]
# ('gas', 'metallicity')_min: 2.5374809500035508e-65 dimensionless
# ('gas', 'metallicity')_min: 0.016873830496898556 dimensionless
# ('gas', 'metallicity')_min: 3.213934215755255e-05 dimensionless
# ('gas', 'metallicity')_min: 55.22107849023716 dimensionless
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)'))]
# ('gas', 'flux_H1_6562.80A')_min: 0.0 cm**(-6)
# ('gas', 'flux_H1_6562.80A')_min: 2.8255765672596004e-15 cm**(-6)
# ('gas', 'flux_H1_6562.80A')_min: 1.492672103111793e-18 cm**(-6)
# ('gas', 'flux_H1_6562.80A')_min: 2.564674876108311e-12 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)'))]
# ('gas', 'luminosity_H1_6562.80A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_H1_6562.80A')_min: 1.0782340963389045e+39 cm**(-3)
# ('gas', 'luminosity_H1_6562.80A')_min: 5.141543615362566e+35 cm**(-3)
# ('gas', 'luminosity_H1_6562.80A')_min: 8.834081984412808e+41 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)'))]
# ('gas', 'flux_O1_1304.86A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O1_1304.86A')_min: 1.6905327354461644e-22 cm**(-6)
# ('gas', 'flux_O1_1304.86A')_min: 8.113772855277284e-26 cm**(-6)
# ('gas', 'flux_O1_1304.86A')_min: 1.3940897903161758e-19 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)'))]
# ('gas', 'luminosity_O1_1304.86A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O1_1304.86A')_min: 7.429014728783568e+31 cm**(-3)
# ('gas', 'luminosity_O1_1304.86A')_min: 2.986016261903729e+28 cm**(-3)
# ('gas', 'luminosity_O1_1304.86A')_min: 5.130504462828963e+34 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)'))]
# ('gas', 'flux_O1_6300.30A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O1_6300.30A')_min: 1.1388682802460427e-20 cm**(-6)
# ('gas', 'flux_O1_6300.30A')_min: 1.425952050364292e-23 cm**(-6)
# ('gas', 'flux_O1_6300.30A')_min: 2.450038016038768e-17 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)'))]
# ('gas', 'luminosity_O1_6300.30A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O1_6300.30A')_min: 5.916558878462676e+33 cm**(-3)
# ('gas', 'luminosity_O1_6300.30A')_min: 4.887780555176357e+30 cm**(-3)
# ('gas', 'luminosity_O1_6300.30A')_min: 8.398072130951248e+36 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)'))]
# ('gas', 'flux_O2_3728.80A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O2_3728.80A')_min: 1.737622707976437e-20 cm**(-6)
# ('gas', 'flux_O2_3728.80A')_min: 1.7351931824733846e-23 cm**(-6)
# ('gas', 'flux_O2_3728.80A')_min: 2.981369016682573e-17 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)'))]
# ('gas', 'luminosity_O2_3728.80A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O2_3728.80A')_min: 1.260359420019783e+34 cm**(-3)
# ('gas', 'luminosity_O2_3728.80A')_min: 8.411863130553064e+30 cm**(-3)
# ('gas', 'luminosity_O2_3728.80A')_min: 1.4453069758064272e+37 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)'))]
# ('gas', 'flux_O2_3726.10A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O2_3726.10A')_min: 4.462650843811073e-20 cm**(-6)
# ('gas', 'flux_O2_3726.10A')_min: 3.707671314794439e-23 cm**(-6)
# ('gas', 'flux_O2_3726.10A')_min: 6.370435576639565e-17 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)'))]
# ('gas', 'luminosity_O2_3726.10A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O2_3726.10A')_min: 2.9102783313921797e+34 cm**(-3)
# ('gas', 'luminosity_O2_3726.10A')_min: 1.5397745046042586e+31 cm**(-3)
# ('gas', 'luminosity_O2_3726.10A')_min: 2.6456051389974314e+37 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)'))]
# ('gas', 'flux_O3_1660.81A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O3_1660.81A')_min: 8.762241953008236e-21 cm**(-6)
# ('gas', 'flux_O3_1660.81A')_min: 2.544760864097575e-24 cm**(-6)
# ('gas', 'flux_O3_1660.81A')_min: 4.3723495871925785e-18 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)'))]
# ('gas', 'luminosity_O3_1660.81A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O3_1660.81A')_min: 6.680940816826915e+32 cm**(-3)
# ('gas', 'luminosity_O3_1660.81A')_min: 4.4287337348762276e+29 cm**(-3)
# ('gas', 'luminosity_O3_1660.81A')_min: 7.609348442388433e+35 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)'))]
# ('gas', 'flux_O3_1666.15A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O3_1666.15A')_min: 2.5659930883747308e-20 cm**(-6)
# ('gas', 'flux_O3_1666.15A')_min: 7.452390692301348e-24 cm**(-6)
# ('gas', 'flux_O3_1666.15A')_min: 1.2804526282526254e-17 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)'))]
# ('gas', 'luminosity_O3_1666.15A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O3_1666.15A')_min: 1.956493795751791e+33 cm**(-3)
# ('gas', 'luminosity_O3_1666.15A')_min: 1.2969659287854985e+30 cm**(-3)
# ('gas', 'luminosity_O3_1666.15A')_min: 2.2284170286228816e+36 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)'))]
# ('gas', 'flux_O3_4363.21A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O3_4363.21A')_min: 1.0443938084265871e-20 cm**(-6)
# ('gas', 'flux_O3_4363.21A')_min: 2.6492918835869663e-24 cm**(-6)
# ('gas', 'flux_O3_4363.21A')_min: 4.551952380665803e-18 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.04439381e-20, 'cm**(-6)'), unyt_quantity(2.64929188e-24, 'cm**(-6)'), unyt_quantity(4.55195238e-18, 'cm**(-6)'))]
# ('gas', 'luminosity_O3_4363.21A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_O3_4363.21A')_min: 8.82298556427389e+32 cm**(-3)
# ('gas', 'luminosity_O3_4363.21A')_min: 5.0962928585760445e+29 cm**(-3)
# ('gas', 'luminosity_O3_4363.21A')_min: 8.756333174869612e+35 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.04439381e-20, 'cm**(-6)'), unyt_quantity(2.64929188e-24, 'cm**(-6)'), unyt_quantity(4.55195238e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.82298556e+32, 'cm**(-3)'), unyt_quantity(5.09629286e+29, 'cm**(-3)'), unyt_quantity(8.75633317e+35, 'cm**(-3)'))]
# ('gas', 'flux_O3_4958.91A')_min: 0.0 cm**(-6)
# ('gas', 'flux_O3_4958.91A')_min: 7.75041713018431e-20 cm**(-6)
# ('gas', 'flux_O3_4958.91A')_min: 2.1946855060391675e-23 cm**(-6)
# ('gas', 'flux_O3_4958.91A')_min: 3.7708581587098584e-17 cm**(-6)
# ...
# ('gas', 'luminosity_S2_6716.44A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_S2_6716.44A')_min: 3.680134850826743e+33 cm**(-3)
# ('gas', 'luminosity_S2_6716.44A')_min: 4.90020351356987e+30 cm**(-3)
# ('gas', 'luminosity_S2_6716.44A')_min: 8.419416972334938e+36 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.04439381e-20, 'cm**(-6)'), unyt_quantity(2.64929188e-24, 'cm**(-6)'), unyt_quantity(4.55195238e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.82298556e+32, 'cm**(-3)'), unyt_quantity(5.09629286e+29, 'cm**(-3)'), unyt_quantity(8.75633317e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(7.75041713e-20, 'cm**(-6)'), unyt_quantity(2.19468551e-23, 'cm**(-6)'), unyt_quantity(3.77085816e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.41246664e+33, 'cm**(-3)'), unyt_quantity(4.85866116e+30, 'cm**(-3)'), unyt_quantity(8.34803986e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.3124016e-19, 'cm** ...
# ('gas', 'flux_S2_6730.82A')_min: 0.0 cm**(-6)
# ('gas', 'flux_S2_6730.82A')_min: 4.818132199251873e-21 cm**(-6)
# ('gas', 'flux_S2_6730.82A')_min: 1.550761555913466e-23 cm**(-6)
# ('gas', 'flux_S2_6730.82A')_min: 2.6644828378547315e-17 cm**(-6)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.04439381e-20, 'cm**(-6)'), unyt_quantity(2.64929188e-24, 'cm**(-6)'), unyt_quantity(4.55195238e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.82298556e+32, 'cm**(-3)'), unyt_quantity(5.09629286e+29, 'cm**(-3)'), unyt_quantity(8.75633317e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(7.75041713e-20, 'cm**(-6)'), unyt_quantity(2.19468551e-23, 'cm**(-6)'), unyt_quantity(3.77085816e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.41246664e+33, 'cm**(-3)'), unyt_quantity(4.85866116e+30, 'cm**(-3)'), unyt_quantity(8.34803986e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.3124016e-19, 'cm** ...
# ('gas', 'luminosity_S2_6730.82A')_min: 0.0 cm**(-3)
# ('gas', 'luminosity_S2_6730.82A')_min: 7.164370938807262e+33 cm**(-3)
# ('gas', 'luminosity_S2_6730.82A')_min: 7.45394220513475e+30 cm**(-3)
# ('gas', 'luminosity_S2_6730.82A')_min: 1.280719205619181e+37 cm**(-3)
# [(unyt_quantity(107.84208924, 'K'), unyt_quantity(7698681.45311589, 'K'), unyt_quantity(11066.68176087, 'K'), unyt_quantity(1.90145181e+10, 'K')), (unyt_quantity(4.60696783e-28, 'g/cm**3'), unyt_quantity(2.75715809e-19, 'g/cm**3'), unyt_quantity(1.77277944e-21, 'g/cm**3'), unyt_quantity(3.04594885e-15, 'g/cm**3')), (unyt_quantity(0.00021092, 'cm**(-3)'), unyt_quantity(126231.33415941, 'cm**(-3)'), unyt_quantity(811.63395821, 'cm**(-3)'), unyt_quantity(1.3945308e+09, 'cm**(-3)')), (unyt_quantity(130.40954755, 'K*cm*dyn/erg'), unyt_quantity(4491566.84599705, 'K*cm*dyn/erg'), unyt_quantity(9055.69543726, 'K*cm*dyn/erg'), unyt_quantity(1.55592876e+10, 'K*cm*dyn/erg')), (unyt_quantity(1.79654166e-51, 'cm**3'), unyt_quantity(10.0200068, 'cm**3'), unyt_quantity(0.00230957, 'cm**3'), unyt_quantity(3968.25272884, 'cm**3')), (unyt_quantity(2.53748095e-65, '(dimensionless)'), unyt_quantity(0.01687383, '(dimensionless)'), unyt_quantity(3.21393422e-05, '(dimensionless)'), unyt_quantity(55.22107849, '(dimensionless)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.82557657e-15, 'cm**(-6)'), unyt_quantity(1.4926721e-18, 'cm**(-6)'), unyt_quantity(2.56467488e-12, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.0782341e+39, 'cm**(-3)'), unyt_quantity(5.14154362e+35, 'cm**(-3)'), unyt_quantity(8.83408198e+41, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.69053274e-22, 'cm**(-6)'), unyt_quantity(8.11377286e-26, 'cm**(-6)'), unyt_quantity(1.39408979e-19, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(7.42901473e+31, 'cm**(-3)'), unyt_quantity(2.98601626e+28, 'cm**(-3)'), unyt_quantity(5.13050446e+34, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.13886828e-20, 'cm**(-6)'), unyt_quantity(1.42595205e-23, 'cm**(-6)'), unyt_quantity(2.45003802e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(5.91655888e+33, 'cm**(-3)'), unyt_quantity(4.88778056e+30, 'cm**(-3)'), unyt_quantity(8.39807213e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.73762271e-20, 'cm**(-6)'), unyt_quantity(1.73519318e-23, 'cm**(-6)'), unyt_quantity(2.98136902e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.26035942e+34, 'cm**(-3)'), unyt_quantity(8.41186313e+30, 'cm**(-3)'), unyt_quantity(1.44530698e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(4.46265084e-20, 'cm**(-6)'), unyt_quantity(3.70767131e-23, 'cm**(-6)'), unyt_quantity(6.37043558e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(2.91027833e+34, 'cm**(-3)'), unyt_quantity(1.5397745e+31, 'cm**(-3)'), unyt_quantity(2.64560514e+37, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(8.76224195e-21, 'cm**(-6)'), unyt_quantity(2.54476086e-24, 'cm**(-6)'), unyt_quantity(4.37234959e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(6.68094082e+32, 'cm**(-3)'), unyt_quantity(4.42873373e+29, 'cm**(-3)'), unyt_quantity(7.60934844e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.56599309e-20, 'cm**(-6)'), unyt_quantity(7.45239069e-24, 'cm**(-6)'), unyt_quantity(1.28045263e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(1.9564938e+33, 'cm**(-3)'), unyt_quantity(1.29696593e+30, 'cm**(-3)'), unyt_quantity(2.22841703e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(1.04439381e-20, 'cm**(-6)'), unyt_quantity(2.64929188e-24, 'cm**(-6)'), unyt_quantity(4.55195238e-18, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.82298556e+32, 'cm**(-3)'), unyt_quantity(5.09629286e+29, 'cm**(-3)'), unyt_quantity(8.75633317e+35, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(7.75041713e-20, 'cm**(-6)'), unyt_quantity(2.19468551e-23, 'cm**(-6)'), unyt_quantity(3.77085816e-17, 'cm**(-6)')), (unyt_quantity(0., 'cm**(-3)'), unyt_quantity(8.41246664e+33, 'cm**(-3)'), unyt_quantity(4.85866116e+30, 'cm**(-3)'), unyt_quantity(8.34803986e+36, 'cm**(-3)')), (unyt_quantity(0., 'cm**(-6)'), unyt_quantity(2.3124016e-19, 'cm** ...

# %%
viz.plot_cumulative_field(ds, sp, width, star_ctr, ('gas', 'flux_H1_6562.80A'),
                              None, 'flux_H1_6562.80A', 'flux_H1_6562,80A_cumulative')
# Out:
# yt : [INFO     ] 2025-04-03 15:29:58,100 Projection completed
# yt : [INFO     ] 2025-04-03 15:29:58,101 xlim = 0.490978 0.491364
# yt : [INFO     ] 2025-04-03 15:29:58,101 ylim = 0.492583 0.492970
# yt : [INFO     ] 2025-04-03 15:29:58,103 xlim = 0.490978 0.491364
# yt : [INFO     ] 2025-04-03 15:29:58,103 ylim = 0.492583 0.492970
# yt : [INFO     ] 2025-04-03 15:29:58,104 Making a fixed resolution buffer of (('gas', 'flux_H1_6562.80A')) 1000 by 1000

# %%
viz.spectra_driver(ds, 1000, 10e-25,
                       lum_lims=[32, 44], flux_lims=[-24, -19], linear=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 viz.spectra_driver(ds, 1000, 10e-25,
#       2                        lum_lims=[32, 44], flux_lims=[-24, -19], linear=False)
#
# File ~/Documents/GitHub/NebularLines/nebular_lines_v2/galaxy_visualization.py:620, in VisualizationManager.spectra_driver(self, ds, resolving_power, noise_lvl, lum_lims, flux_lims, linear)
#     604 '''
#     605 Generate spectra.
#     606
#    (...)
#     616     i.e. flux_lims=[-24, -19]
#     617 '''
#     619 cosmo = FlatLambdaCDM(H0=70, Om0=self.omega_matter)  # around 0.3
# --> 620 d_1 = cosmo.luminosity_distance(self.redshift)*3.086e24  # Mpc to cm
#     621 self.flux_arr = (self.luminosities / (4 * np.pi * d_1 ** 2)).value
#     623 fname = os.path.join(self.directory, self.output_file)
#
# AttributeError: 'VisualizationManager' object has no attribute 'redshift'
